# %% [markdown]
# <a href="https://colab.research.google.com/github/Apidwalin/-DESKTOP-9QGAS69-tensorflow1/blob/Apidwalin-patch-1/Apidwalin_hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
2021-06-15T08:08:06.4326813Z ##[section]Starting: Request a runner to run this job
2021-06-15T08:08:06.8334896Z Can't find any online and idle self-hosted runner in current repository that matches the required labels: 'ubuntu-latest'
2021-06-15T08:08:06.9122468Z Can't find any online and idle self-hosted runner in current repository's organization account that matches the required labels: 'ubuntu-latest'
2021-06-15T08:08:08.2231486Z Found online and idle hosted runner in current repository's organization account that matches the required labels: 'ubuntu-latest'
2021-06-15T08:08:08.4385574Z ##[section]Finishing: Request a runner to run this job
2021-06-15T08:08:15.8018006Z Current runner version: '2.278.0'
2021-06-15T08:08:15.8047064Z ##[group]Operating System
2021-06-15T08:08:15.8048012Z Ubuntu
2021-06-15T08:08:15.8048430Z 20.04.2
2021-06-15T08:08:15.8048992Z LTS
2021-06-15T08:08:15.8049583Z ##[endgroup]
2021-06-15T08:08:15.8050273Z ##[group]Virtual Environment
2021-06-15T08:08:15.8050978Z Environment: ubuntu-20.04
2021-06-15T08:08:15.8051535Z Version: 20210606.1
2021-06-15T08:08:15.8052834Z Included Software: https://github.com/actions/virtual-environments/blob/ubuntu20/20210606.1/images/linux/Ubuntu2004-README.md
2021-06-15T08:08:15.8054246Z Image Release: https://github.com/actions/virtual-environments/releases/tag/ubuntu20%2F20210606.1
2021-06-15T08:08:15.8055359Z ##[endgroup]
2021-06-15T08:08:15.8057636Z ##[group]GITHUB_TOKEN Permissions
2021-06-15T08:08:15.8058871Z Actions: write
2021-06-15T08:08:15.8059433Z Checks: write
2021-06-15T08:08:15.8059949Z Contents: write
2021-06-15T08:08:15.8060497Z Deployments: write
2021-06-15T08:08:15.8061141Z Discussions: write
2021-06-15T08:08:15.8061711Z Issues: write
2021-06-15T08:08:15.8062173Z Metadata: read
2021-06-15T08:08:15.8062720Z Packages: write
2021-06-15T08:08:15.8063272Z PullRequests: write
2021-06-15T08:08:15.8063856Z RepositoryProjects: write
2021-06-15T08:08:15.8064514Z SecurityEvents: write
2021-06-15T08:08:15.8065028Z Statuses: write
2021-06-15T08:08:15.8065687Z ##[endgroup]
2021-06-15T08:08:15.8069206Z Prepare workflow directory
2021-06-15T08:08:15.8815953Z Prepare all required actions
2021-06-15T08:08:15.8830675Z Getting action download info
2021-06-15T08:08:16.3247183Z Download action repository 'actions/checkout@v2'
2021-06-15T08:08:18.2942059Z ##[group]Run actions/checkout@v2
2021-06-15T08:08:18.2942772Z with:
2021-06-15T08:08:18.2943316Z   repository: Apidwalin/hello-world
2021-06-15T08:08:18.2944263Z   token: ***
2021-06-15T08:08:18.2944735Z   ssh-strict: true
2021-06-15T08:08:18.2945395Z   persist-credentials: true
2021-06-15T08:08:18.2945906Z   clean: true
2021-06-15T08:08:18.2946326Z   fetch-depth: 1
2021-06-15T08:08:18.2946777Z   lfs: false
2021-06-15T08:08:18.2947195Z   submodules: false
2021-06-15T08:08:18.2947641Z ##[endgroup]
2021-06-15T08:08:19.0574519Z Syncing repository: Apidwalin/hello-world
2021-06-15T08:08:19.0575456Z ##[group]Getting Git version info
2021-06-15T08:08:19.0576717Z Working directory is '/home/runner/work/hello-world/hello-world'
2021-06-15T08:08:19.0577432Z [command]/usr/bin/git version
2021-06-15T08:08:19.0577894Z git version 2.31.1
2021-06-15T08:08:19.0578797Z ##[endgroup]
2021-06-15T08:08:19.0579658Z Deleting the contents of '/home/runner/work/hello-world/hello-world'
2021-06-15T08:08:19.0580906Z ##[group]Initializing the repository
2021-06-15T08:08:19.0581823Z [command]/usr/bin/git init /home/runner/work/hello-world/hello-world
2021-06-15T08:08:19.0582799Z hint: Using 'master' as the name for the initial branch. This default branch name
2021-06-15T08:08:19.0583595Z hint: is subject to change. To configure the initial branch name to use in all
2021-06-15T08:08:19.0584371Z hint: of your new repositories, which will suppress this warning, call:
2021-06-15T08:08:19.0584971Z hint: 
2021-06-15T08:08:19.0585678Z hint: 	git config --global init.defaultBranch <name>
2021-06-15T08:08:19.0586230Z hint: 
2021-06-15T08:08:19.0586939Z hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
2021-06-15T08:08:19.0587900Z hint: 'development'. The just-created branch can be renamed via this command:
2021-06-15T08:08:19.0588497Z hint: 
2021-06-15T08:08:19.0589062Z hint: 	git branch -m <name>
2021-06-15T08:08:19.0589970Z Initialized empty Git repository in /home/runner/work/hello-world/hello-world/.git/
2021-06-15T08:08:19.0591105Z [command]/usr/bin/git remote add origin https://github.com/Apidwalin/hello-world
2021-06-15T08:08:19.0591831Z ##[endgroup]
2021-06-15T08:08:19.0592390Z ##[group]Disabling automatic garbage collection
2021-06-15T08:08:19.0593207Z [command]/usr/bin/git config --local gc.auto 0
2021-06-15T08:08:19.0593729Z ##[endgroup]
2021-06-15T08:08:19.0595320Z ##[group]Setting up auth
2021-06-15T08:08:19.0596526Z [command]/usr/bin/git config --local --name-only --get-regexp core\.sshCommand
2021-06-15T08:08:19.0598781Z [command]/usr/bin/git submodule foreach --recursive git config --local --name-only --get-regexp 'core\.sshCommand' && git config --local --unset-all 'core.sshCommand' || :
2021-06-15T08:08:19.0600412Z [command]/usr/bin/git config --local --name-only --get-regexp http\.https\:\/\/github\.com\/\.extraheader
2021-06-15T08:08:19.0602641Z [command]/usr/bin/git submodule foreach --recursive git config --local --name-only --get-regexp 'http\.https\:\/\/github\.com\/\.extraheader' && git config --local --unset-all 'http.https://github.com/.extraheader' || :
2021-06-15T08:08:19.0604364Z [command]/usr/bin/git config --local http.https://github.com/.extraheader AUTHORIZATION: basic ***
2021-06-15T08:08:19.0605204Z ##[endgroup]
2021-06-15T08:08:19.0605718Z ##[group]Fetching the repository
2021-06-15T08:08:19.0607371Z [command]/usr/bin/git -c protocol.version=2 fetch --no-tags --prune --progress --no-recurse-submodules --depth=1 origin +ec84860ba7519c1d23c2616c485b537f93e284b8:refs/remotes/origin/main
2021-06-15T08:08:19.0608600Z remote: Enumerating objects: 14, done.        
2021-06-15T08:08:19.0609178Z remote: Counting objects:   7% (1/14)        
2021-06-15T08:08:19.0609735Z remote: Counting objects:  14% (2/14)        
2021-06-15T08:08:19.0610274Z remote: Counting objects:  21% (3/14)        
2021-06-15T08:08:19.0610829Z remote: Counting objects:  28% (4/14)        
2021-06-15T08:08:19.0611369Z remote: Counting objects:  35% (5/14)        
2021-06-15T08:08:19.0612071Z remote: Counting objects:  42% (6/14)        
2021-06-15T08:08:19.0612659Z remote: Counting objects:  50% (7/14)        
2021-06-15T08:08:19.0613198Z remote: Counting objects:  57% (8/14)        
2021-06-15T08:08:19.0613748Z remote: Counting objects:  64% (9/14)        
2021-06-15T08:08:19.0614290Z remote: Counting objects:  71% (10/14)        
2021-06-15T08:08:19.0615799Z remote: Counting objects:  78% (11/14)        
2021-06-15T08:08:19.0616531Z remote: Counting objects:  85% (12/14)        
2021-06-15T08:08:19.0617170Z remote: Counting objects:  92% (13/14)        
2021-06-15T08:08:19.0618393Z remote: Counting objects: 100% (14/14)        
2021-06-15T08:08:19.0619143Z remote: Counting objects: 100% (14/14), done.        
2021-06-15T08:08:19.0619911Z remote: Compressing objects:   8% (1/12)        
2021-06-15T08:08:19.0620690Z remote: Compressing objects:  16% (2/12)        
2021-06-15T08:08:19.0621357Z remote: Compressing objects:  25% (3/12)        
2021-06-15T08:08:19.0622028Z remote: Compressing objects:  33% (4/12)        
2021-06-15T08:08:19.0622702Z remote: Compressing objects:  41% (5/12)        
2021-06-15T08:08:19.0624196Z remote: Compressing objects:  50% (6/12)        
2021-06-15T08:08:19.0624940Z remote: Compressing objects:  58% (7/12)        
2021-06-15T08:08:19.0625610Z remote: Compressing objects:  66% (8/12)        
2021-06-15T08:08:19.0626289Z remote: Compressing objects:  75% (9/12)        
2021-06-15T08:08:19.0627176Z remote: Compressing objects:  83% (10/12)        
2021-06-15T08:08:19.0627814Z remote: Compressing objects:  91% (11/12)        
2021-06-15T08:08:19.0628454Z remote: Compressing objects: 100% (12/12)        
2021-06-15T08:08:19.0629282Z remote: Compressing objects: 100% (12/12), done.        
2021-06-15T08:08:19.0630393Z remote: Total 14 (delta 0), reused 0 (delta 0), pack-reused 0        
2021-06-15T08:08:19.0631424Z From https://github.com/Apidwalin/hello-world
2021-06-15T08:08:19.0632860Z  * [new ref]         ec84860ba7519c1d23c2616c485b537f93e284b8 -> origin/main
2021-06-15T08:08:19.0633555Z ##[endgroup]
2021-06-15T08:08:19.0634097Z ##[group]Determining the checkout info
2021-06-15T08:08:19.0634623Z ##[endgroup]
2021-06-15T08:08:19.0635089Z ##[group]Checking out the ref
2021-06-15T08:08:19.0635999Z [command]/usr/bin/git checkout --progress --force -B main refs/remotes/origin/main
2021-06-15T08:08:19.0637145Z Switched to a new branch 'main'
2021-06-15T08:08:19.0638054Z Branch 'main' set up to track remote branch 'main' from 'origin'.
2021-06-15T08:08:19.0638916Z ##[endgroup]
2021-06-15T08:08:19.0639672Z [command]/usr/bin/git log -1 --format='%H'
2021-06-15T08:08:19.0640591Z 'ec84860ba7519c1d23c2616c485b537f93e284b8'
2021-06-15T08:08:19.0752303Z ##[group]Run echo Hello, world!
2021-06-15T08:08:19.0753011Z [36;1mecho Hello, world![0m
2021-06-15T08:08:19.0796162Z shell: /usr/bin/bash -e {0}
2021-06-15T08:08:19.0796653Z ##[endgroup]
2021-06-15T08:08:19.0872492Z Hello, world!
2021-06-15T08:08:19.0911970Z ##[group]Run echo Add other actions to build,
2021-06-15T08:08:19.0912784Z [36;1mecho Add other actions to build,[0m
2021-06-15T08:08:19.0913675Z [36;1mecho test, and deploy your project.[0m
2021-06-15T08:08:19.0956075Z shell: /usr/bin/bash -e {0}
2021-06-15T08:08:19.0956626Z ##[endgroup]
2021-06-15T08:08:19.1030950Z Add other actions to build,
2021-06-15T08:08:19.1031882Z test, and deploy your project.
2021-06-15T08:08:19.1105310Z Post job cleanup.
2021-06-15T08:08:19.2365126Z [command]/usr/bin/git version
2021-06-15T08:08:19.2409902Z git version 2.31.1
2021-06-15T08:08:19.2460308Z [command]/usr/bin/git config --local --name-only --get-regexp core\.sshCommand
2021-06-15T08:08:19.2493554Z [command]/usr/bin/git submodule foreach --recursive git config --local --name-only --get-regexp 'core\.sshCommand' && git config --local --unset-all 'core.sshCommand' || :
2021-06-15T08:08:19.2752143Z [command]/usr/bin/git config --local --name-only --get-regexp http\.https\:\/\/github\.com\/\.extraheader
2021-06-15T08:08:19.2775426Z http.https://github.com/.extraheader
2021-06-15T08:08:19.2786711Z [command]/usr/bin/git config --local --unset-all http.https://github.com/.extraheader
2021-06-15T08:08:19.2817927Z [command]/usr/bin/git submodule foreach --recursive git config --local --name-only --get-regexp 'http\.https\:\/\/github\.com\/\.extraheader' && git config --local --unset-all 'http.https://github.com/.extraheader' || :
2021-06-15T08:08:19.3141103Z Cleaning up orphan processes
